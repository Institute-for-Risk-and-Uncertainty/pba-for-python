# %% [markdown]
# # PBA for Python demo
#
# PBA can be imported in the normal way

# %%
import pba

# %% [markdown]
# ## Intervals
# Intervals can be specified using `pba.Interval` or `pba.I`
# Arithmetic operations (+,-,*,/) can be performed on intervals
# Outputted intervals can be printed

# %%
a = pba.Interval(0,1)
b = pba.I(3,4)
c = pba.I(10,20)
d = pba.Interval(5,8)

e = a+b
f = b-2
g = c*d
h = d/c

print(e)
print(f)
print(g)
print(h)
# Out:
# Interval [3, 5]
# Interval [1, 2]
# Interval [50, 160]
# Interval [0.25, 0.8]

# %% [markdown]
# ## p-boxes
# P-boxes can be specified by using a distribution name with interval inputs

# %%
x = pba.N(pba.I(-1,1),1)

# %% [markdown]
# P-boxes can be visualised using show() method

# %%
x.show()
# Out:
# /Users/lesliec/Documents/Github_repos/pba-for-python/pba/pbox.py:865: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
x.steps
# Out:
# 200

# %%
y = pba.U(pba.I(1,2),pba.I(3,4))
y.show()

# %%
y.steps
# Out:
# 50

# %% [markdown]
# Arithmetic can be performed between p-boxes and intervals

# %%
y = pba.U(pba.I(1,2),pba.I(3,4))
w = y+a
z = x-y
y.show()
# Out:
# ---------------------------------------------------------------------------
# ArithmeticError                           Traceback (most recent call last)
# Cell In[6], line 3
#       1 y = pba.U(pba.I(1,2),pba.I(3,4))
#       2 w = y+a
# ----> 3 z = x-y
#       4 y.show()
#
# File ~/Documents/Github_repos/pba-for-python/pba/pbox.py:216, in Pbox.__sub__(self, other)
#     215 def __sub__(self,other):
# --> 216     return self.sub(other, method = 'f')
#
# File ~/Documents/Github_repos/pba-for-python/pba/pbox.py:496, in Pbox.sub(self, other, method)
#     493 elif method == 'p':
#     494     method = 'o'
# --> 496 return self.add(-other, method)
#
# File ~/Documents/Github_repos/pba-for-python/pba/pbox.py:329, in Pbox.add(self, other, method)
#     326 if other.__class__.__name__ == 'Pbox':
#     328     if self.steps != other.steps:
# --> 329         raise ArithmeticError("Both Pboxes must have the same number of steps")
#     331     if method == 'f':
#     333         nleft  = np.empty(self.steps)
#
# ArithmeticError: Both Pboxes must have the same number of steps
