# %%
import pba

# %%
a = pba.what_I_know(mean = 120, std = 10, minimum = 50, debug=True)
a.show()
# Out:
#  min_mean  pos_mean_std  mean_std
# /Users/nickgray/Local/pbacode/pba-for-python/pba/pbox.py:800: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
